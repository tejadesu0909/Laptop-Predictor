# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('laptop.csv')
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 Company   TypeName Inches  \
# 0             0         0.0   Apple  Ultrabook   13.3
# 1             1         1.0   Apple  Ultrabook   13.3
# 2             2         2.0      HP   Notebook   15.6
# 3             3         3.0   Apple  Ultrabook   15.4
# 4             4         4.0   Apple  Ultrabook   13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# ...

# %%
df.drop(columns=["Unnamed: 0.1"	,"Unnamed: 0"], axis=1, inplace=True)

# %%
df.sample(7)
# Out:
#      Company            TypeName Inches                 ScreenResolution  \
# 158     Dell  2 in 1 Convertible   15.6  Full HD / Touchscreen 1920x1080
# 878     Dell            Notebook   15.6                Full HD 1920x1080
# 151     Dell              Gaming   15.6                Full HD 1920x1080
# 90      Asus              Gaming   15.6                Full HD 1920x1080
# 820   Lenovo            Notebook   15.6                         1366x768
# 124     Acer            Notebook   15.6                         1366x768
# 1175    Asus            Notebook     14                Full HD 1920x1080
#
#                               Cpu  Ram                Memory  \
# 158    Intel Core i7 8550U 1.8GHz  8GB             256GB SSD
# 878    Intel Core i5 7200U 2.5GHz  4GB  128GB SSD +  1TB HDD
# 151   Intel Core i7 7700HQ 2.8GHz  8GB          1.0TB Hybrid
# 90              AMD FX 9830P 3GHz  8GB               1TB HDD
# 820      Intel Core i3 6006U 2GHz  4GB             500GB HDD
# ...

# %%
df.isnull().sum()
# Out:
# Company             30
# TypeName            30
# Inches              30
# ScreenResolution    30
# Cpu                 30
# Ram                 30
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              30
# Price               30
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 58

# %% [markdown]
# dropped duplciates

# %%
df.drop_duplicates(inplace=True)

# %%
# df.drop(columns='Weight', inplace=True, axis=1)

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram',
#        'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
df.sample(4)
# Out:
#     Company            TypeName Inches  \
# 743  Lenovo  2 in 1 Convertible     14
# 996      HP           Ultrabook   13.3
# 620      HP            Notebook     14
# 95     Acer  2 in 1 Convertible   13.3
#
#                               ScreenResolution                         Cpu  \
# 743            Full HD / Touchscreen 1920x1080  Intel Core i5 7200U 2.5GHz
# 996  IPS Panel Full HD / Touchscreen 1920x1080  Intel Core i7 7500U 2.7GHz
# 620                                   1366x768  Intel Core i5 7300U 2.6GHz
# 95   IPS Panel Full HD / Touchscreen 1920x1080  Intel Core i5 8250U 1.6GHz
#
#      Ram     Memory                     Gpu       OpSys  Weight     Price
# 743  8GB  256GB SSD   Intel HD Graphics 620  Windows 10   1.7kg  53226.72
# 996  8GB  256GB SSD   Intel HD Graphics 620  Windows 10  1.11kg  71874.72
# 620  8GB  256GB SSD   Intel HD Graphics 620  Windows 10  2.31kg  59886.72
# 95   8GB  256GB SSD  Intel UHD Graphics 620  Windows 10   1.5kg  45128.16

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1245 entries, 0 to 1273
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1244 non-null   object
#  1   TypeName          1244 non-null   object
#  2   Inches            1244 non-null   object
#  3   ScreenResolution  1244 non-null   object
#  4   Cpu               1244 non-null   object
#  5   Ram               1244 non-null   object
#  6   Memory            1244 non-null   object
#  7   Gpu               1244 non-null   object
#  8   OpSys             1244 non-null   object
#  9   Weight            1244 non-null   object
#  10  Price             1244 non-null   float64
# dtypes: float64(1), object(10)
# memory usage: 116.7+ KB

# %%
df.dropna(inplace=True)

# %%
df[['Width', 'Height']] = df['ScreenResolution'].str.extract(r'(\d+)x(\d+)')

# %%
df.ScreenResolution.unique()
# Out:
# array(['IPS Panel Retina Display 2560x1600', '1440x900',
#        'Full HD 1920x1080', 'IPS Panel Retina Display 2880x1800',
#        '1366x768', 'IPS Panel Full HD 1920x1080',
#        'IPS Panel Retina Display 2304x1440',
#        'IPS Panel Full HD / Touchscreen 1920x1080',
#        'Full HD / Touchscreen 1920x1080',
#        'Touchscreen / Quad HD+ 3200x1800', 'Touchscreen 2256x1504',
#        'Quad HD+ / Touchscreen 3200x1800', 'IPS Panel 1366x768',
#        'IPS Panel 4K Ultra HD / Touchscreen 3840x2160',
#        'IPS Panel Full HD 2160x1440',
#        '4K Ultra HD / Touchscreen 3840x2160', '1600x900',
#        'IPS Panel 4K Ultra HD 3840x2160', '4K Ultra HD 3840x2160',
#        'Touchscreen 1366x768', 'Touchscreen 2560x1440',
#        'IPS Panel Full HD 1366x768', 'IPS Panel 2560x1440',
#        'IPS Panel Full HD 2560x1440',
#        'IPS Panel Retina Display 2736x1824', 'Touchscreen 2400x1600',
#        '2560x1440', 'IPS Panel Quad HD+ 2560x1440',
# ...

# %%
df.sample(4)
# Out:
#     Company   TypeName Inches                     ScreenResolution  \
# 803    Dell   Notebook   15.6  4K Ultra HD / Touchscreen 3840x2160
# 15    Apple  Ultrabook   13.3   IPS Panel Retina Display 2560x1600
# 733    Acer   Notebook   15.6                             1366x768
# 914    Acer   Notebook   15.6                    Full HD 1920x1080
#
#                              Cpu  Ram     Memory  \
# 803  Intel Core i5 7300HQ 2.5GHz  8GB  256GB SSD
# 15          Intel Core i5 2.3GHz  8GB  256GB SSD
# 733   Intel Core i5 7200U 2.5GHz  4GB  500GB HDD
# 914   Intel Core i3 7100U 2.4GHz  4GB    1TB HDD
#
#                               Gpu       OpSys  Weight      Price Width Height
# 803       Nvidia GeForce GTX 1050  Windows 10  2.06kg  93186.720  3840   2160
# 15   Intel Iris Plus Graphics 640       macOS  1.37kg  80908.344  2560   1600
# 733         Intel HD Graphics 620  Windows 10   2.4kg  29783.520  1366    768
# ...

# %%
df.drop(columns='ScreenResolution', inplace=True)

# %%
# df.Inches.astype(float)

# %%
df.loc[df.eq('?').any(axis=1)]
# Out:
#     Company     TypeName Inches                          Cpu   Ram     Memory  \
# 208    Dell    Ultrabook   13.3   Intel Core i7 8550U 1.8GHz   8GB  256GB SSD
# 476    Dell  Workstation      ?  Intel Core i7 7700HQ 2.8GHz   8GB  256GB SSD
# 770    Dell     Notebook   15.6   Intel Core i7 7500U 2.7GHz  16GB          ?
#
#                         Gpu       OpSys  Weight        Price Width Height
# 208  Intel UHD Graphics 620  Windows 10       ?   77202.7200  1920   1080
# 476     Nvidia Quadro M1200  Windows 10  1.78kg  128298.2400  1920   1080
# 770      AMD Radeon R7 M445  Windows 10   2.3kg   62938.0656  1920   1080

# %%
df.drop(df.loc[df.eq("?").any(axis=1)].index, inplace=True)

# %%
df['Inches'] = df.Inches.astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1241 entries, 0 to 1273
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Company   1241 non-null   object
#  1   TypeName  1241 non-null   object
#  2   Inches    1241 non-null   float64
#  3   Cpu       1241 non-null   object
#  4   Ram       1241 non-null   object
#  5   Memory    1241 non-null   object
#  6   Gpu       1241 non-null   object
#  7   OpSys     1241 non-null   object
#  8   Weight    1241 non-null   object
#  9   Price     1241 non-null   float64
#  10  Width     1241 non-null   object
#  11  Height    1241 non-null   object
# dtypes: float64(2), object(10)
# memory usage: 126.0+ KB

# %%
df.shape
# Out:
# (1241, 12)

# %%
df.sample(4)
# Out:
#      Company  TypeName  Inches                                   Cpu  Ram  \
# 739     Acer  Notebook    15.6              Intel Core i3 6006U 2GHz  4GB
# 863   Lenovo    Gaming    15.6           Intel Core i5 7300HQ 2.5GHz  8GB
# 393      MSI    Gaming    17.3           Intel Core i7 7700HQ 2.8GHz  8GB
# 1254    Dell  Notebook    15.6  Intel Pentium Quad Core N3700 1.6GHz  4GB
#
#          Memory                         Gpu       OpSys Weight       Price  \
# 739   500GB HDD       Intel HD Graphics 520  Windows 10  2.4kg  21887.4240
# 863     1TB HDD     Nvidia GeForce GTX 1050       No OS  2.5kg  54185.7600
# 393   256GB SSD  Nvidia GeForce GTX 1050 Ti  Windows 10  2.7kg  71874.7200
# 1254  500GB HDD           Intel HD Graphics  Windows 10  2.2kg  23655.7872
#
#      Width Height
# 739   1366    768
# 863   1920   1080
# 393   1920   1080
# 1254  1366    768

# %%
df.Ram = df.Ram.str.replace("GB", "")

# %%
df.sample(4)
# Out:
#     Company     TypeName  Inches                          Cpu Ram     Memory  \
# 252    Asus     Notebook    15.6      AMD A9-Series 9420 3GHz   4    1TB HDD
# 410  Lenovo  Workstation    15.6  Intel Core i7 7700HQ 2.8GHz   8  512GB SSD
# 950      HP  Workstation    15.6  Intel Core i7 6820HQ 2.7GHz   8    8GB SSD
# 499  Lenovo     Notebook    15.6   Intel Core i5 7200U 2.5GHz   8  256GB SSD
#
#                        Gpu       OpSys  Weight      Price Width Height
# 252     AMD Radeon R5 M420  Windows 10  1.68kg   24988.32  1366    768
# 410    Nvidia Quadro M1200  Windows 10  2.67kg  102564.00  1920   1080
# 950   Nvidia Quadro M1000M  Windows 10   2.0kg  119826.72  1920   1080
# 499  Intel HD Graphics 620  Windows 10   2.3kg   48538.08  1920   1080

# %% [markdown]
# to convert the Company, Typename, Opsys columns we will use the map function and assing numbers for each type,

# %% [markdown]
# now we need to focus on to split Cpu, Memory, Gpu

# %%
df.Cpu.unique()
# Out:
# array(['Intel Core i5 2.3GHz', 'Intel Core i5 1.8GHz',
#        'Intel Core i5 7200U 2.5GHz', 'Intel Core i7 2.7GHz',
#        'Intel Core i5 3.1GHz', 'AMD A9-Series 9420 3GHz',
#        'Intel Core i7 2.2GHz', 'Intel Core i7 8550U 1.8GHz',
#        'Intel Core i5 8250U 1.6GHz', 'Intel Core i3 6006U 2GHz',
#        'Intel Core i7 2.8GHz', 'Intel Core M m3 1.2GHz',
#        'Intel Core i7 7500U 2.7GHz', 'Intel Core i7 2.9GHz',
#        'Intel Core i3 7100U 2.4GHz', 'Intel Core i5 7300HQ 2.5GHz',
#        'AMD E-Series E2-9000e 1.5GHz', 'Intel Core i5 1.6GHz',
#        'Intel Core i7 8650U 1.9GHz', 'Intel Atom x5-Z8300 1.44GHz',
#        'AMD E-Series E2-6110 1.5GHz', 'AMD A6-Series 9220 2.5GHz',
#        'Intel Celeron Dual Core N3350 1.1GHz',
#        'Intel Core i3 7130U 2.7GHz', 'Intel Core i7 7700HQ 2.8GHz',
#        'Intel Core i5 2.0GHz', 'AMD Ryzen 1700 3GHz',
#        'Intel Pentium Quad Core N4200 1.1GHz',
# ...

# %%
df['Cpu_Speed'] = df['Cpu'].str.split(" ").apply(lambda x:x[-1])

# %%
df.Cpu_Speed = df.Cpu_Speed.str.replace("GHz", "")

# %%
df = df.rename(columns={"Cpu_Speed": "Cpu_Clock_Speed"})

# %%
df['Cpu_brand'] = df["Cpu"].str.split(" ").apply(lambda x:x[0])

# %%
df['Cpu_processor'] = df["Cpu"].apply(lambda x: ' '.join(x.split()[1:-1]))

# %%
df.drop(columns = 'Cpu', inplace=True)

# %%
df['Memory'] = df['Memory'].str.replace('\.0', '', regex=True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\desut\AppData\Local\Temp\ipykernel_13496\55261193.py:1: SyntaxWarning: invalid escape sequence '\.'
#   df['Memory'] = df['Memory'].str.replace('\.0', '', regex=True)

# %%
df.Memory.unique()
# Out:
# array(['128GB SSD', '128GB Flash Storage', '256GB SSD', '512GB SSD',
#        '500GB HDD', '256GB Flash Storage', '1TB HDD',
#        '128GB SSD +  1TB HDD', '256GB SSD +  256GB SSD',
#        '64GB Flash Storage', '32GB Flash Storage', '256GB SSD +  1TB HDD',
#        '256GB SSD +  2TB HDD', '32GB SSD', '2TB HDD', '64GB SSD',
#        '1TB Hybrid', '512GB SSD +  1TB HDD', '1TB SSD',
#        '256GB SSD +  500GB HDD', '128GB SSD +  2TB HDD',
#        '512GB SSD +  512GB SSD', '16GB SSD', '16GB Flash Storage',
#        '512GB SSD +  256GB SSD', '512GB SSD +  2TB HDD',
#        '64GB Flash Storage +  1TB HDD', '180GB SSD', '1TB HDD +  1TB HDD',
#        '32GB HDD', '1TB SSD +  1TB HDD', '512GB Flash Storage',
#        '128GB HDD', '240GB SSD', '8GB SSD', '508GB Hybrid',
#        '512GB SSD +  1TB Hybrid', '256GB SSD +  1TB Hybrid'], dtype=object)

# %%
df['Memory'] = df['Memory'].str.replace('GB', '')
df['Memory'] = df['Memory'].str.replace('TB', '000')

# %%
df.Memory.unique()
# Out:
# array(['128 SSD', '128 Flash Storage', '256 SSD', '512 SSD', '500 HDD',
#        '256 Flash Storage', '1000 HDD', '128 SSD +  1000 HDD',
#        '256 SSD +  256 SSD', '64 Flash Storage', '32 Flash Storage',
#        '256 SSD +  1000 HDD', '256 SSD +  2000 HDD', '32 SSD', '2000 HDD',
#        '64 SSD', '1000 Hybrid', '512 SSD +  1000 HDD', '1000 SSD',
#        '256 SSD +  500 HDD', '128 SSD +  2000 HDD', '512 SSD +  512 SSD',
#        '16 SSD', '16 Flash Storage', '512 SSD +  256 SSD',
#        '512 SSD +  2000 HDD', '64 Flash Storage +  1000 HDD', '180 SSD',
#        '1000 HDD +  1000 HDD', '32 HDD', '1000 SSD +  1000 HDD',
#        '512 Flash Storage', '128 HDD', '240 SSD', '8 SSD', '508 Hybrid',
#        '512 SSD +  1000 Hybrid', '256 SSD +  1000 Hybrid'], dtype=object)

# %%
new = df.Memory.str.split('+' ,n=1, expand=True)

df['first'] = new[0]
df['second'] = new[1]

df['first'] = df['first'].str.strip()

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches Ram    Memory  \
# 1222      HP            Notebook    15.6   6  1000 HDD
# 1262    Dell            Notebook    15.6   6  1000 HDD
# 221   Lenovo  2 in 1 Convertible    14.0   8   256 SSD
# 94      Asus           Ultrabook    14.0   8   256 SSD
# 1184      HP            Notebook    15.6   6  1000 HDD
#
#                           Gpu       OpSys  Weight     Price Width Height  \
# 1222           AMD Radeon 530  Windows 10   2.1kg  28185.12  1920   1080
# 1262    Intel HD Graphics 620  Windows 10   2.3kg  24455.52  1366    768
# 221    Intel UHD Graphics 620  Windows 10  1.74kg  47898.72  1920   1080
# 94      Intel HD Graphics 620  Windows 10  1.25kg  55890.72  1920   1080
# 1184  Nvidia GeForce GTX 960M  Windows 10  2.18kg  42570.72  1920   1080
#
#      Cpu_Clock_Speed Cpu_brand     Cpu_processor     first second
# 1222             2.7       AMD  A12-Series 9720P  1000 HDD   None
# ...

# %%
df['Layer1hdd'] = df['first'].apply(lambda x:1 if 'HDD' in x else 0)

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches Ram               Memory  \
# 1129      HP              Gaming    17.3   8  128 SSD +  1000 HDD
# 306       HP  2 in 1 Convertible    13.3  16              256 SSD
# 454     Dell            Notebook    15.6   8  128 SSD +  1000 HDD
# 188     Acer           Ultrabook    13.3   8              256 SSD
# 1121      HP            Notebook    13.3   8              256 SSD
#
#                           Gpu       OpSys  Weight      Price Width Height  \
# 1129  Nvidia GeForce GTX 1060  Windows 10  3.35kg   60153.12  1920   1080
# 306     Intel HD Graphics 620  Windows 10  1.28kg  105228.00  1920   1080
# 454            AMD Radeon 530  Windows 10  2.36kg   52161.12  1920   1080
# 188     Intel HD Graphics 615  Windows 10  1.12kg   52693.92  1920   1080
# 1121    Intel HD Graphics 520  Windows 10  1.16kg   90043.20  1920   1080
#
#      Cpu_Clock_Speed Cpu_brand   Cpu_processor    first      second  Layer1hdd
# ...

# %%
df['Layer1ssd'] = df['first'].apply(lambda x:1 if 'SSD' in x else 0)
df['Layer1flashstorage'] = df['first'].apply(lambda x:1 if 'Flash Storage' in x else 0)
df['Layer1hybrid'] = df['first'].apply(lambda x:1 if 'Hybrid' in x else 0)

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches Ram               Memory  \
# 266     Asus  2 in 1 Convertible    13.3   8   512 SSD +  512 SSD
# 1247    Asus              Gaming    15.6  16  256 SSD +  1000 HDD
# 585      MSI              Gaming    17.3  16  128 SSD +  1000 HDD
# 333   Lenovo            Notebook    15.6   4             1000 HDD
# 908   Lenovo            Notebook    15.6   8  128 SSD +  1000 HDD
#
#                           Gpu       OpSys  Weight      Price Width Height  \
# 266    Intel UHD Graphics 620  Windows 10   4.1kg   79866.72  1920   1080
# 1247  Nvidia GeForce GTX 1070  Windows 10  2.34kg  123876.00  1920   1080
# 585   Nvidia GeForce GTX 980M  Windows 10   4.5kg  125154.72  1920   1080
# 333     Intel HD Graphics 520  Windows 10  1.85kg   23922.72  1920   1080
# 908   Nvidia GeForce GTX 960M  Windows 10   2.6kg   42037.92  1920   1080
#
#      Cpu_Clock_Speed Cpu_brand   Cpu_processor     first      second  \
# ...

# %%
df['first'] = df['first'].str.replace(r'\D', '')
# df['first'] = df['first'].str.replace('\D', '', regex=True)

# %%
df.sample(5)
# Out:
#      Company   TypeName  Inches Ram               Memory  \
# 1181  Lenovo  Ultrabook    15.6   6              256 SSD
# 544     Asus   Notebook    15.6   4              500 HDD
# 40      Asus   Notebook    15.6   4             1000 HDD
# 355     Dell   Notebook    15.6   8  128 SSD +  2000 HDD
# 1141     MSI     Gaming    15.6   8  128 SSD +  1000 HDD
#
#                           Gpu       OpSys  Weight      Price Width Height  \
# 1181      Nvidia GeForce 920M  Windows 10  1.54kg  44275.680  1920   1080
# 544    AMD Radeon R2 Graphics  Windows 10     2kg  18594.720  1366    768
# 40      Intel HD Graphics 620       Linux     2kg  20725.920  1920   1080
# 355            AMD Radeon 530  Windows 10  2.02kg  51729.552  1920   1080
# 1141  Nvidia GeForce GTX 1050  Windows 10   2.4kg  60888.384  1920   1080
#
#      Cpu_Clock_Speed Cpu_brand   Cpu_processor     first      second  \
# 1181             2.7     Intel   Core i7 7500U   256 SSD        None
# ...

# %%
df.second.fillna("0", inplace=True)
# Out:
# C:\Users\desut\AppData\Local\Temp\ipykernel_13496\643578445.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.second.fillna("0", inplace=True)

# %%
df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)
# df['second'] = df['second'].str.replace(r'\D', '')
df['second'] = df['second'].str.replace('\D', '', regex=True)
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\D'
# <>:6: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\desut\AppData\Local\Temp\ipykernel_13496\2979549318.py:6: SyntaxWarning: invalid escape sequence '\D'
#   df['second'] = df['second'].str.replace('\D', '', regex=True)

# %%
df.sample(5)
# Out:
#     Company   TypeName  Inches Ram               Memory  \
# 7     Apple  Ultrabook    13.3   8    256 Flash Storage
# 153     MSI     Gaming    17.3  16  256 SSD +  1000 HDD
# 131    Dell   Notebook    15.6   4             1000 HDD
# 243    Dell     Gaming    15.6   8              256 SSD
# 76   Lenovo   Notebook    15.6   8             2000 HDD
#
#                          Gpu       OpSys  Weight       Price Width  ...  \
# 7     Intel HD Graphics 6000       macOS  1.34kg   61735.536  1440  ...
# 153  Nvidia GeForce GTX 1060  Windows 10   2.8kg  100699.200  1920  ...
# 131       AMD Radeon R5 M430  Windows 10   2.2kg   23922.720  1920  ...
# 243  Nvidia GeForce GTX 1050  Windows 10  2.56kg   46833.120  1920  ...
# 76     Intel HD Graphics 620       No OS   2.2kg   27652.320  1920  ...
#
#                  first second Layer1hdd Layer1ssd Layer1flashstorage  \
# 7    256 Flash Storage      0         0         0                  1
# ...

# %%
df['second'] = df['second'].str.replace('\D', '', regex=True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\desut\AppData\Local\Temp\ipykernel_13496\4163997917.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df['second'] = df['second'].str.replace('\D', '', regex=True)

# %%
df["second"] = df["second"].astype(int)

# %%
df['first'] = df['first'].str.replace('\D', '', regex=True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\desut\AppData\Local\Temp\ipykernel_13496\1308373819.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df['first'] = df['first'].str.replace('\D', '', regex=True)

# %%
df["first"] = df["first"].astype(int)

# %%
df.sample(5)
# Out:
#       Company  TypeName  Inches Ram               Memory  \
# 1230   Lenovo   Netbook    12.5  16              512 SSD
# 139        HP  Notebook    13.3   4              256 SSD
# 621    Lenovo  Notebook    14.0   8              256 SSD
# 984   Toshiba  Notebook    14.0   4              500 HDD
# 659      Dell    Gaming    17.3  32  512 SSD +  1000 HDD
#
#                           Gpu       OpSys  Weight        Price Width  ...  \
# 1230    Intel HD Graphics 520  Windows 10   1.3kg   87912.0000  1920  ...
# 139     Intel HD Graphics 620  Windows 10  1.32kg   37242.7200  1920  ...
# 621     Intel HD Graphics 520   Windows 7  1.65kg   78055.2000  1920  ...
# 984     Intel HD Graphics 520  Windows 10  1.75kg   48751.2000  1366  ...
# 659   Nvidia GeForce GTX 1070  Windows 10  4.42kg  167691.8736  3840  ...
#
#      first second Layer1hdd Layer1ssd  Layer1flashstorage  Layer1hybrid  \
# 1230   512      0         0         1                   0             0
# ...

# %%
df['Memory_1'] = (df['first']* (df.Layer1ssd+df.Layer1hdd+df.Layer1hybrid+df.Layer1flashstorage)
+df['second'] * (df.Layer2SSD+df.Layer2HDD+df.Layer2Hybrid+df.Layer2Flash_Storage))

# %%
df.sample(5)
# Out:
#      Company     TypeName  Inches Ram    Memory                     Gpu  \
# 712     Dell     Notebook    15.6   8  1000 HDD   Intel HD Graphics 620
# 1055      HP     Notebook    15.6   4   500 HDD   Intel HD Graphics 520
# 662   Lenovo     Notebook    15.6   4   500 HDD   Intel HD Graphics 520
# 80      Dell    Ultrabook    15.6   8   256 SSD  Intel UHD Graphics 620
# 1086      HP  Workstation    15.6   8   256 SSD      AMD FirePro W4190M
#
#            OpSys  Weight       Price Width  ... second Layer1hdd Layer1ssd  \
# 712        Linux  1.98kg  38681.2800  1920  ...      0         1         0
# 1055  Windows 10  2.31kg  37570.3920  1366  ...      0         1         0
# 662   Windows 10   2.2kg  28504.8000  1920  ...      0         1         0
# 80    Windows 10  1.88kg  58403.4048  1920  ...      0         0         1
# 1086   Windows 7   1.9kg  79653.6000  1920  ...      0         0         1
#
#      Layer1flashstorage  Layer1hybrid  Layer2HDD  Layer2SSD  Layer2Hybrid  \
# ...

# %%
df["HDD"]=(df["first"]*df["Layer1hdd"]+df["second"]*df["Layer2HDD"])

# %%
df['SSD'] = (df["first"] * df["Layer1ssd"] + df["second"] * df["Layer2SSD"])
df['FlashStorage'] = (df["first"] * df["Layer1flashstorage"] + df["second"] * df["Layer2Flash_Storage"])
df['Hybrid'] = (df["first"] * df["Layer1hybrid"] + df["second"] * df["Layer2Hybrid"])

# %%
df.sample(5)
# Out:
#     Company            TypeName  Inches Ram               Memory  \
# 558      HP            Notebook    15.6   6              128 SSD
# 722  Lenovo           Ultrabook    14.0   8              256 SSD
# 977    Asus  2 in 1 Convertible    15.6  16  512 SSD +  2000 HDD
# 112  Lenovo  2 in 1 Convertible    13.3   8              256 SSD
# 388    Dell         Workstation    15.6   8              256 SSD
#
#                          Gpu       OpSys  Weight       Price Width  ...  \
# 558           AMD Radeon 530  Windows 10  1.91kg   30310.992  1920  ...
# 722    Intel HD Graphics 620  Windows 10  1.32kg   79866.720  1920  ...
# 977  Nvidia GeForce GTX 950M  Windows 10   2.3kg   95850.720  3840  ...
# 112    Intel HD Graphics 620  Windows 10  1.37kg   74538.720  1920  ...
# 388      Nvidia Quadro M1200  Windows 10     2kg  113752.800  1920  ...
#
#     Layer1hybrid Layer2HDD Layer2SSD Layer2Hybrid  Layer2Flash_Storage  \
# ...

# %%
df.Width = df.Width.astype(int)
df.Height = df.Height.astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1241 entries, 0 to 1273
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Company              1241 non-null   object
#  1   TypeName             1241 non-null   object
#  2   Inches               1241 non-null   float64
#  3   Ram                  1241 non-null   object
#  4   Memory               1241 non-null   object
#  5   Gpu                  1241 non-null   object
#  6   OpSys                1241 non-null   object
#  7   Weight               1241 non-null   object
#  8   Price                1241 non-null   float64
#  9   Width                1241 non-null   int32
#  10  Height               1241 non-null   int32
#  11  Cpu_Clock_Speed      1241 non-null   object
#  12  Cpu_brand            1241 non-null   object
#  13  Cpu_processor        1241 non-null   object
#  14  first                1241 non-null   int32
# ...

# %%
df["PPI"]=(((df["Width"]**2+df["Height"]**2)**(1/2))/df["Inches"]).astype(float)

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches Ram               Memory  \
# 819     Dell            Notebook    14.0   4              500 HDD
# 1119    Asus              Gaming    17.3   8  128 SSD +  1000 HDD
# 757       HP         Workstation    15.6   8              256 SSD
# 508       HP           Ultrabook    13.3   8              512 SSD
# 23      Dell  2 in 1 Convertible    13.3   8              256 SSD
#
#                           Gpu       OpSys  Weight       Price  Width  ...  \
# 819     Intel HD Graphics 520  Windows 10  1.76kg  40226.4000   1366  ...
# 1119  Nvidia GeForce GTX 960M  Windows 10  3.52kg  69929.4672   1920  ...
# 757      Nvidia Quadro M1000M   Windows 7  2.59kg  83170.0800   1920  ...
# 508     Intel HD Graphics 620  Windows 10  1.34kg  70489.4400   1920  ...
# 23     Intel UHD Graphics 620  Windows 10  1.62kg  43636.3200   1920  ...
#
#       Layer2HDD Layer2SSD Layer2Hybrid Layer2Flash_Storage  Memory_1   HDD  \
# ...

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'Ram', 'Memory', 'Gpu', 'OpSys',
#        'Weight', 'Price', 'Width', 'Height', 'Cpu_Clock_Speed', 'Cpu_brand',
#        'Cpu_processor', 'first', 'second', 'Layer1hdd', 'Layer1ssd',
#        'Layer1flashstorage', 'Layer1hybrid', 'Layer2HDD', 'Layer2SSD',
#        'Layer2Hybrid', 'Layer2Flash_Storage', 'Memory_1', 'HDD', 'SSD',
#        'FlashStorage', 'Hybrid', 'PPI'],
#       dtype='object')

# %%
df.drop(columns = ["Inches",'Memory', 'Width', 'Height', 'first', 'second', 'Layer1hdd', 'Layer1ssd',
       'Layer1flashstorage', 'Layer1hybrid', 'Layer2HDD', 'Layer2SSD',
       'Layer2Hybrid', 'Layer2Flash_Storage'], axis =1, inplace=True )
df.rename(columns = {'Memory_1': 'Memory_count'})
# Out:
#      Company            TypeName Ram                           Gpu  \
# 0      Apple           Ultrabook   8  Intel Iris Plus Graphics 640
# 1      Apple           Ultrabook   8        Intel HD Graphics 6000
# 2         HP            Notebook   8         Intel HD Graphics 620
# 3      Apple           Ultrabook  16            AMD Radeon Pro 455
# 4      Apple           Ultrabook   8  Intel Iris Plus Graphics 650
# ...      ...                 ...  ..                           ...
# 1269    Asus            Notebook   4           Nvidia GeForce 920M
# 1270  Lenovo  2 in 1 Convertible   4         Intel HD Graphics 520
# 1271  Lenovo  2 in 1 Convertible  16         Intel HD Graphics 520
# 1272  Lenovo            Notebook   2             Intel HD Graphics
# 1273      HP            Notebook   6            AMD Radeon R5 M330
#
#            OpSys  Weight        Price Cpu_Clock_Speed Cpu_brand  \
# 0          macOS  1.37kg   71378.6832             2.3     Intel
# ...

# %%
df = df.rename(columns = {'Memory_1': 'Memory_count'})

# %%
df.sample(5)
# Out:
#      Company            TypeName Ram                    Gpu       OpSys  \
# 1045      HP            Notebook   8  Intel HD Graphics 520  Windows 10
# 338     Asus            Notebook   4  Intel HD Graphics 500       Linux
# 1139      HP           Ultrabook   8  Intel HD Graphics 520   Windows 7
# 313     Acer            Notebook   8          AMD Radeon R5  Windows 10
# 1260  Lenovo  2 in 1 Convertible   4  Intel HD Graphics 520  Windows 10
#
#       Weight        Price Cpu_Clock_Speed Cpu_brand            Cpu_processor  \
# 1045  1.84kg  112065.9552             2.4     Intel            Core i5 6300U
# 338      2kg   14651.4672             1.1     Intel  Celeron Dual Core N3350
# 1139  1.88kg  115709.2416             2.5     Intel            Core i7 6500U
# 313   2.23kg   24988.3200             2.2       AMD           A8-Series 7410
# 1260   1.8kg   44382.7728             2.3     Intel            Core i5 6200U
#
#       Memory_count   HDD  SSD  FlashStorage  Hybrid         PPI
# ...

# %%
df.Gpu.unique()
# Out:
# array(['Intel Iris Plus Graphics 640', 'Intel HD Graphics 6000',
#        'Intel HD Graphics 620', 'AMD Radeon Pro 455',
#        'Intel Iris Plus Graphics 650', 'AMD Radeon R5',
#        'Intel Iris Pro Graphics', 'Nvidia GeForce MX150',
#        'Intel UHD Graphics 620', 'Intel HD Graphics 520',
#        'AMD Radeon Pro 555', 'AMD Radeon R5 M430',
#        'Intel HD Graphics 615', 'AMD Radeon Pro 560',
#        'Nvidia GeForce 940MX', 'Nvidia GeForce GTX 1050', 'AMD Radeon R2',
#        'AMD Radeon 530', 'Nvidia GeForce 930MX', 'Intel HD Graphics',
#        'Intel HD Graphics 500', 'Nvidia GeForce 930MX ',
#        'Nvidia GeForce GTX 1060', 'Nvidia GeForce 150MX',
#        'Intel Iris Graphics 540', 'AMD Radeon RX 580',
#        'Nvidia GeForce 920MX', 'AMD Radeon R4 Graphics', 'AMD Radeon 520',
#        'Nvidia GeForce GTX 1070', 'Nvidia GeForce GTX 1050 Ti',
#        'Intel HD Graphics 400', 'Nvidia GeForce MX130', 'AMD R4 Graphics',
# ...

# %%
df[['Gpu_brand', 'Gpu_model']] = df['Gpu'].str.split(n=1, expand=True)

# %%
df = df.drop(columns = 'Gpu')

# %%
df.sample(5)
# Out:
#     Company            TypeName Ram       OpSys  Weight       Price  \
# 281    Dell            Notebook   4       Linux  2.25kg  22803.8400
# 226    Dell            Notebook  16  Windows 10   2.3kg  45768.0528
# 261  Lenovo            Notebook   4       No OS   2.2kg  23656.3200
# 415    Dell            Notebook   4       Linux   2.3kg  31909.3920
# 924  Lenovo  2 in 1 Convertible   8  Windows 10  1.37kg  97236.0000
#
#     Cpu_Clock_Speed Cpu_brand  Cpu_processor  Memory_count   HDD  SSD  \
# 281             2.0     Intel  Core i3 6006U          1000  1000    0
# 226             2.7     Intel  Core i7 7500U          1000  1000    0
# 261               2     Intel  Core i3 6006U           256     0  256
# 415             2.5     Intel  Core i5 7200U           256     0  256
# 924             2.5     Intel  Core i5 7200U           512     0  512
#
#      FlashStorage  Hybrid         PPI Gpu_brand        Gpu_model
# 281             0       0  141.211998       AMD   Radeon R5 M430
# ...

# %%
df.OpSys.value_counts()
# Out:
# OpSys
# Windows 10      1019
# No OS             63
# Linux             57
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            1
# Name: count, dtype: int64

# %%
df.sample(5)
# Out:
#      Company   TypeName Ram       OpSys  Weight      Price Cpu_Clock_Speed  \
# 32        HP   Notebook   4  Windows 10  2.71kg   23389.92             2.5
# 93      Dell     Gaming   8  Windows 10  2.65kg   63669.60             2.5
# 1157  Lenovo  Ultrabook  12   Windows 7   1.4kg  122490.72             2.6
# 72      Dell   Notebook   8  Windows 10   2.2kg   46353.60             1.8
# 1083      HP  Ultrabook  16  Windows 10   1.3kg  109170.72             2.7
#
#      Cpu_brand   Cpu_processor  Memory_count  HDD  SSD  FlashStorage  Hybrid  \
# 32         AMD  A6-Series 9220           500  500    0             0       0
# 93       Intel  Core i5 7300HQ           256    0  256             0       0
# 1157     Intel   Core i7 6600U           512    0  512             0       0
# 72       Intel   Core i7 8550U           256    0  256             0       0
# 1083     Intel   Core i7 7500U           512    0  512             0       0
#
#              PPI Gpu_brand         Gpu_model
# ...

# %%
df.isnull().sum()
# Out:
# Company            0
# TypeName           0
# Ram                0
# OpSys              0
# Weight             0
# Price              0
# Cpu_Clock_Speed    0
# Cpu_brand          0
# Cpu_processor      0
# Memory_count       0
# HDD                0
# SSD                0
# FlashStorage       0
# Hybrid             0
# PPI                0
# Gpu_brand          0
# Gpu_model          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1241 entries, 0 to 1273
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Company          1241 non-null   object
#  1   TypeName         1241 non-null   object
#  2   Ram              1241 non-null   object
#  3   OpSys            1241 non-null   object
#  4   Weight           1241 non-null   object
#  5   Price            1241 non-null   float64
#  6   Cpu_Clock_Speed  1241 non-null   object
#  7   Cpu_brand        1241 non-null   object
#  8   Cpu_processor    1241 non-null   object
#  9   Memory_count     1241 non-null   int64
#  10  HDD              1241 non-null   int64
#  11  SSD              1241 non-null   int64
#  12  FlashStorage     1241 non-null   int64
#  13  Hybrid           1241 non-null   int64
#  14  PPI              1241 non-null   float64
#  15  Gpu_brand        1241 non-null   object
#  16  Gpu_model        1241 non-null   object
# ...

# %%
df.Ram = df.Ram.astype(int)

# %%
df.Cpu_Clock_Speed = df.Cpu_Clock_Speed.astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1241 entries, 0 to 1273
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Company          1241 non-null   object
#  1   TypeName         1241 non-null   object
#  2   Ram              1241 non-null   int32
#  3   OpSys            1241 non-null   object
#  4   Weight           1241 non-null   object
#  5   Price            1241 non-null   float64
#  6   Cpu_Clock_Speed  1241 non-null   float64
#  7   Cpu_brand        1241 non-null   object
#  8   Cpu_processor    1241 non-null   object
#  9   Memory_count     1241 non-null   int64
#  10  HDD              1241 non-null   int64
#  11  SSD              1241 non-null   int64
#  12  FlashStorage     1241 non-null   int64
#  13  Hybrid           1241 non-null   int64
#  14  PPI              1241 non-null   float64
#  15  Gpu_brand        1241 non-null   object
#  16  Gpu_model        1241 non-null   object
# ...

# %%
px.box(df.SSD)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Cpu_Clock_Speed  \
# 0   Apple  Ultrabook    8  macOS  1.37kg   71378.6832              2.3
# 1   Apple  Ultrabook    8  macOS  1.34kg   47895.5232              1.8
# 2      HP   Notebook    8  No OS  1.86kg   30636.0000              2.5
# 3   Apple  Ultrabook   16  macOS  1.83kg  135195.3360              2.7
# 4   Apple  Ultrabook    8  macOS  1.37kg   96095.8080              3.1
#
#   Cpu_brand  Cpu_processor  Memory_count  HDD  SSD  FlashStorage  Hybrid  \
# 0     Intel        Core i5           128    0  128             0       0
# 1     Intel        Core i5           128    0    0           128       0
# 2     Intel  Core i5 7200U           256    0  256             0       0
# 3     Intel        Core i7           512    0  512             0       0
# 4     Intel        Core i5           256    0  256             0       0
#
#           PPI Gpu_brand               Gpu_model
# 0  226.983005     Intel  Iris Plus Graphics 640
# ...

# %% [markdown]
# Converting Price column from inr to usd.

# %%
exchange_Rate = 0.012
df['Price_USD'] = df['Price']* exchange_Rate

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Cpu_Clock_Speed  \
# 0   Apple  Ultrabook    8  macOS  1.37kg   71378.6832              2.3
# 1   Apple  Ultrabook    8  macOS  1.34kg   47895.5232              1.8
# 2      HP   Notebook    8  No OS  1.86kg   30636.0000              2.5
# 3   Apple  Ultrabook   16  macOS  1.83kg  135195.3360              2.7
# 4   Apple  Ultrabook    8  macOS  1.37kg   96095.8080              3.1
#
#   Cpu_brand  Cpu_processor  Memory_count  HDD  SSD  FlashStorage  Hybrid  \
# 0     Intel        Core i5           128    0  128             0       0
# 1     Intel        Core i5           128    0    0           128       0
# 2     Intel  Core i5 7200U           256    0  256             0       0
# 3     Intel        Core i7           512    0  512             0       0
# 4     Intel        Core i5           256    0  256             0       0
#
#           PPI Gpu_brand               Gpu_model    Price_USD
# ...

# %%
df.drop(columns='Price', inplace=True)

# %%
df.drop(df.loc[df.Ram == 1].index, inplace=True)

# %%
df.drop(columns = 'Memory_count', inplace = True)

# %%
df['Weight'] = df['Weight'].str.replace('kg', "")

# %%
df.sample(5)
# Out:
#      Company            TypeName  Ram       OpSys Weight  Cpu_Clock_Speed  \
# 1186    Dell  2 in 1 Convertible   16  Windows 10   2.09              2.7
# 569   Lenovo            Notebook    4  Windows 10   2.02              2.5
# 605      MSI              Gaming   16  Windows 10    1.8              2.8
# 1036      HP            Notebook    4  Windows 10   2.04              2.5
# 62    Lenovo            Notebook    8       No OS    1.7              2.7
#
#      Cpu_brand   Cpu_processor   HDD  SSD  FlashStorage  Hybrid         PPI  \
# 1186     Intel   Core i7 7500U     0  512             0       0  141.211998
# 569      Intel   Core i5 7200U   500    0             0       0  111.935204
# 605      Intel  Core i7 7700HQ  2000  256             0       0  282.423996
# 1036     Intel   Core i5 7200U   500    0             0       0  100.454670
# 62       Intel   Core i3 7130U     0  256             0       0  157.350512
#
#      Gpu_brand         Gpu_model   Price_USD
# ...

# %%
original_df = df.copy()

# %%
original_df.head()
# Out:
#   Company   TypeName  Ram  OpSys Weight  Cpu_Clock_Speed Cpu_brand  \
# 0   Apple  Ultrabook    8  macOS   1.37              2.3     Intel
# 1   Apple  Ultrabook    8  macOS   1.34              1.8     Intel
# 2      HP   Notebook    8  No OS   1.86              2.5     Intel
# 3   Apple  Ultrabook   16  macOS   1.83              2.7     Intel
# 4   Apple  Ultrabook    8  macOS   1.37              3.1     Intel
#
#    Cpu_processor  HDD  SSD  FlashStorage  Hybrid         PPI Gpu_brand  \
# 0        Core i5    0  128             0       0  226.983005     Intel
# 1        Core i5    0    0           128       0  127.677940     Intel
# 2  Core i5 7200U    0  256             0       0  141.211998     Intel
# 3        Core i7    0  512             0       0  220.534624       AMD
# 4        Core i5    0  256             0       0  226.983005     Intel
#
#                 Gpu_model    Price_USD
# 0  Iris Plus Graphics 640   856.544198
# 1        HD Graphics 6000   574.746278
# ...

# %%
for col in df.columns:
    print(col, ' ', len(df[col].value_counts()), 'labels')
# Out:
# Company   19 labels
# TypeName   6 labels
# Ram   9 labels
# OpSys   9 labels
# Weight   188 labels
# Cpu_Clock_Speed   25 labels
# Cpu_brand   3 labels
# Cpu_processor   93 labels
# HDD   6 labels
# SSD   13 labels
# FlashStorage   7 labels
# Hybrid   3 labels
# PPI   47 labels
# Gpu_brand   4 labels
# Gpu_model   110 labels
# Price_USD   775 labels

# %%
df.TypeName.value_counts()
# Out:
# TypeName
# Notebook              688
# Gaming                203
# Ultrabook             188
# 2 in 1 Convertible    111
# Workstation            28
# Netbook                22
# Name: count, dtype: int64

# %%
df['Cpu_processor'] = df['Cpu_processor'].apply( lambda x: ' ' .join(x.split()[0:2]))
df = df.drop(columns = 'Gpu_model')

# %%
df.TypeName = df.TypeName.replace("Netbook", "Notebook")

# %%
df.Weight = df.Weight.astype(float)

# %%
original_df = df.copy()

# %%
df.sample(5)
# Out:
#      Company   TypeName  Ram       OpSys  Weight  Cpu_Clock_Speed Cpu_brand  \
# 510     Dell  Ultrabook    8  Windows 10    1.29              2.5     Intel
# 184   Xiaomi   Notebook    8       No OS    1.95              1.6     Intel
# 813     Dell   Notebook    8  Windows 10    1.98              2.7     Intel
# 189     Dell   Notebook    8  Windows 10    2.80              1.8     Intel
# 1081  Lenovo     Gaming   32  Windows 10    4.60              2.7     Intel
#
#      Cpu_processor   HDD  SSD  FlashStorage  Hybrid         PPI Gpu_brand  \
# 510        Core i5     0  128             0       0  165.632118     Intel
# 184        Core i5     0  256             0       0  141.211998    Nvidia
# 813        Core i7  1000    0             0       0  141.211998    Nvidia
# 189        Core i7  1000  128             0       0  127.335675       AMD
# 1081       Core i7     0  512             0    1000  127.335675    Nvidia
#
#        Price_USD
# 510    574.78464
# 184    766.59264
# ...

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight  Cpu_Clock_Speed Cpu_brand  \
# 0   Apple  Ultrabook    8  macOS    1.37              2.3     Intel
# 1   Apple  Ultrabook    8  macOS    1.34              1.8     Intel
# 2      HP   Notebook    8  No OS    1.86              2.5     Intel
# 3   Apple  Ultrabook   16  macOS    1.83              2.7     Intel
# 4   Apple  Ultrabook    8  macOS    1.37              3.1     Intel
#
#   Cpu_processor  HDD  SSD  FlashStorage  Hybrid         PPI Gpu_brand  \
# 0       Core i5    0  128             0       0  226.983005     Intel
# 1       Core i5    0    0           128       0  127.677940     Intel
# 2       Core i5    0  256             0       0  141.211998     Intel
# 3       Core i7    0  512             0       0  220.534624       AMD
# 4       Core i5    0  256             0       0  226.983005     Intel
#
#      Price_USD
# 0   856.544198
# 1   574.746278
# 2   367.632000
# 3  1622.344032
# 4  1153.149696

# %%
df['Price_USD'].describe()
# Out:
# count    1240.000000
# mean      726.507846
# std       449.183589
# min       111.248640
# 25%       391.101307
# 50%       632.007360
# 75%       957.761280
# max      3899.456640
# Name: Price_USD, dtype: float64

# %%
df.to_excel('laptop_preprocessed.xlsx')
